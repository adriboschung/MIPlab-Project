# %% [markdown]
# # Mars Mission Experiment

# %% [markdown]
# ### Goals of the project
#
# - Reproduce the experiment done on fMRI data with iEEG data
# - Explore data, both pre-processed iEEG and behavioral data (reaction time, memory, ...)
# - Role of hipocampus and regions involved (anterior, posterior, lateral, ...)

# %% [markdown]
# ### Steps
# - Read and understand the python scripts used for fMRI data (and iEEG done?)
# - Get comfortable with the data
# - Verify what has been done for iEEG (preprocessing, scripts, ...)
# - Go through NSSP class again (relevant parts)
# - Papers for iEEG?
# -

# %% [markdown]
# ### Additional Notes
# - Read the 63 pages paper sent by Guillaume, good way to learn about the project
# - MNE package description is also well done and explains well
# - PWP done by ...
# - The main goal is to do the same analysis as in the paper, but take time to explore the data and find new interesting features
# -
