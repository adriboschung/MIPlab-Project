# %% [markdown]
# # Mars Mission Experiment

# %% [markdown]
# ### Goals of the project
#
# - Reproduce the experiment done on fMRI data with iEEG data
# - Explore data, both pre-processed iEEG and behavioral data (reaction time, memory, ...)
# - Role of hipocampus and regions involved (anterior, posterior, lateral, ...)
# - Is there a difference in activity depending on the frequency band (Theta, Beta, HpR, ...)

# %% [markdown]
# ### Steps
# - Read and understand the python scripts used for fMRI data (and iEEG done?)
# - Preprocessing steps to check: (p.19 of 63 pages paper)
#     1. Identify channels expected to show meaningful neural signals (especially sEEG where some electrodes outside brainor in white matter)
#     2. Identifying channels/time segments that include epileptiform activity / contaminated by physiological and non-phys. artifacts.
#     3. Re-referencing signals --> derive signal that are less affected by distant activity (not sure of what it means, see different methods in the paper under 3.4)
#
# - Get comfortable with the data --> do some vizualisation
# - Verify what has been done for iEEG (preprocessing, scripts, ...)
# - Go through NSSP class again (relevant parts)
# - Papers for iEEG?
# -

# %% [markdown]
# ### Additional Notes
# - Read the 63 pages paper sent by Guillaume, good way to learn about the project
# - MNE package description is also well done and explains well
# - PWP done by ...
# - The main goal is to do the same analysis as in the paper, but take time to explore the data and find new interesting features
# -

# %% [markdown]
# ### Problems solutions
# - coordinate (250x250x250) --> (250x250x100)
# - rotation
# - use normalized space

# %% [markdown]
# ## Questions
#
# - Should i use data from /media/RCPNAS/sEEG_MARS_Alison/sourcedata/seeg/sub-02/PA_1987/EEG_6865.TRC
# OR
# /media/RCPNAS/sEEG_MARS_Alison/sub-02/ses-retrieval/ieeg
# - Is the filtering done or should I do it each time I load the data?
# - How to get the condition labels? rn I have 1,2,3,4,5,6,7 but i dont know whic one is past,futur, ...

# %% [markdown]
# ### Note for next week
# - analyse bande theta + temps-fréquence,
# - gamma?,
# - bande fréquence,
# - référencement bipolaire --> haute fréquence(ex: bas/haut gamma),
# - average reference --> basse fréquence (ex: theta (+ gamma si on fait du coupling)),
# --> attention electrode dehors (retirer),
# - utiliser .TRC,
